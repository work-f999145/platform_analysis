# %%
import pandas as pd
import re
from bs4 import BeautifulSoup as BS
import requests

# %%
import requests

cookies = {
    '_session_id': '86e0108b37bd7b2ce181460d5d77ed0c',
    'dpr': '1',
    '_gid': 'GA1.2.656478961.1724844375',
    '_gat_gtag_UA_119969665_1': '1',
    '_ym_uid': '1724844376419101617',
    '_ym_d': '1724844376',
    '_ym_isad': '2',
    '_ym_visorc': 'w',
    '_ga_9NBHXKFZ51': 'GS1.1.1724844375.1.1.1724844387.0.0.0',
    '_ga': 'GA1.1.327693481.1724844375',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,de;q=0.6',
    # 'cookie': '_session_id=86e0108b37bd7b2ce181460d5d77ed0c; dpr=1; _gid=GA1.2.656478961.1724844375; _gat_gtag_UA_119969665_1=1; _ym_uid=1724844376419101617; _ym_d=1724844376; _ym_isad=2; _ym_visorc=w; _ga_9NBHXKFZ51=GS1.1.1724844375.1.1.1724844387.0.0.0; _ga=GA1.1.327693481.1724844375',
    'priority': 'u=1, i',
    'referer': 'https://pereezdmarket.ru/katalog-upakovki/korobki/korobki-dlya-pereezda',
    'sec-ch-ua': '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36',
    'x-csrf-token': 'xWCR55+KIPXP8U8HRWm5bPgMldafrXX/AOuUdDFk54squLMvtqoplSpeVHCjmsqMI3hNoVqh6VnYxzDTJ1F1aA==',
    'x-requested-with': 'XMLHttpRequest',
}

params = {
    'sort': 'position',
    'direction': 'asc',
    'page': '1',
}

response = requests.get(
    'https://pereezdmarket.ru/katalog-upakovki/korobki/korobki-dlya-pereezda.json',
    params=params,
    # cookies=cookies,
    # headers=headers,
)
response.json()
# Out:
# {'products': [{'id': 944,
#    'name': 'Самосборная картонная коробка №186 130х40х40 мм',
#    'position': 27,
#    'list_name': 'Самосборная картонная коробка №186 130х40х40 мм',
#    'list_description': 'Размеры:  13x4x4 см',
#    'slug': 'kartonnaya-korobka-186-13x4x4-sm',
#    'path': '/kartonnaya-korobka-186-13x4x4-sm',
#    'section_image': {'id': 9292700,
#     'file': {'url': '/images/009/292/700/9292700/original/%D0%A1%D0%B0%D0%BC%D0%BE%D1%81%D0%B1%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D0%BA%D0%B0%D1%80%D1%82%D0%BE%D0%BD%D0%BD%D0%B0%D1%8F_%D0%BA%D0%BE%D1%80%D0%BE%D0%B1%D0%BA%D0%B0_186_13%D1%854%D1%854_%D1%81%D0%BC.__02.png'},
#     'name': 'Самосборная_картонная_коробка_186_13х4х4_см.__02.png',
#     'path': '/images/009/292/700/9292700/',
#     'size': 345249,
#     'type': 'image',
#     'width': 1000,
#     'height': 1000,
#     'success': 1,
# ...

# %%
with open('data/test/test.html', 'wb') as f:
    f.write(response.content)
