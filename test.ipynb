# %%
import pandas as pd

# %%
df = pd.read_clipboard(header=None).rename(columns={0:'region', 1:'market', 2:'site', 3:'type'})
df
# Out:
#           region          market  \
# 0    Москва и МО          Pack24
# 1        Москва       Русскартон
# 2    Москва и МО          Ронбел
# 3         Москва  ВсяУпаковка.ру
# 4         Москва        Гофромир
# ..           ...             ...
# 216  Москва и МО           Ромул
# 217       Москва       Картонпак
# 218  Москва и МО         Guardix
# 219       Москва       Pack Boom
# 220       Москва         Вестком
#
#                                                   site              type
# 0                                            pack24.ru             склад
# 1                                        russcarton.ru      производство
# 2                                            ronbel.ru      производство
# 3                                      vsyaupakovka.ru    магазин, склад
# 4                                          gofromir.ru      производство
# ..                                                 ...               ...
# ...

# %%
print(list(df['market'].value_counts().items()))
# Out:
# [('Упаковка', 3), ('Картон Пак', 2), ('Петрокороб', 2), ('ТараТам', 2), ('Гофропродпак', 2), ('Гофротара', 2), ('Мир Упаковки', 2), ('Packmarket', 1), ('Факел', 1), ('Фервет', 1), ('Переезд Маркет', 1), ('Московская Картонная Фабрика', 1), ('Аксель Пак', 1), ('Комупак', 1), ('Allbox', 1), ('Pack-store', 1), ('Pack24', 1), ('Русскартон', 1), ('Ронбел', 1), ('ВсяУпаковка.ру', 1), ('Pack-craft', 1), ('Коробкофф', 1), ('Бета-Пак', 1), ('GorodPak', 1), ('Упакуйкин.ру', 1), ('Hobbypack', 1), ('Гофроцентр', 1), ('Seller Logistic', 1), ('Pro картон', 1), ('Фабрика упаковки', 1), ('Тара-товара', 1), ('УниТехУпак', 1), ('Центр упаковки', 1), ('Антэк', 1), ('Cargo-avto (Авто-транс)', 1), ('Яропак', 1), ('Selfpacking', 1), ('Союз заводов', 1), ('Контур Пак', 1), ('За коробкой', 1), ('Craft Room', 1), ('Гофралюкс', 1), ('Пакхаус', 1), ('ГофроАльянс', 1), ('Партнер71', 1), ('Купи коробку', 1), ('Альба-упаковка', 1), ('Павло-Посадский гофрокомбинат', 1), ('Центральная типография', 1), ('Партия-Пак'
# ...

# %%
df.query('market == "Упаковка"')
# Out:
#           region    market                                               site  \
# 68   Новосибирск  Упаковка                    Главная | Вся Упаковка (nsk.ru)
# 104       Казань  Упаковка  Коробки из гофрокартона купить оптом в Казани ...
# 170       Москва  Упаковка  Картонные коробки оптом — производство, продаж...
#
#                  type
# 68              склад
# 104  интернет-магазин
# 170      производство
