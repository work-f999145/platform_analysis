# %%
import pandas as pd
import re
from bs4 import BeautifulSoup as BS
import requests
import json

# %%
import requests

cookies = {
    'ab__device': 'desktop',
    'sid_customer_s_b6318': 'bcfd49569817443b3a79f026d1083b8e-C',
    'ab__device': 'desktop',
    'ab__ab_ib': 'N',
    '_gcl_au': '1.1.1399473051.1724847143',
    '_gid': 'GA1.2.562965300.1724847143',
    '_ym_uid': '1724847143789558175',
    '_ym_d': '1724847143',
    '_ym_isad': '2',
    '_ym_visorc': 'w',
    '_ga_XMNE5956ME': 'GS1.1.1724847143.1.1.1724847172.31.0.0',
    '_ga': 'GA1.2.243157588.1724847143',
}

headers = {
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,de;q=0.6',
    # 'cookie': 'ab__device=desktop; sid_customer_s_b6318=bcfd49569817443b3a79f026d1083b8e-C; ab__device=desktop; ab__ab_ib=N; _gcl_au=1.1.1399473051.1724847143; _gid=GA1.2.562965300.1724847143; _ym_uid=1724847143789558175; _ym_d=1724847143; _ym_isad=2; _ym_visorc=w; _ga_XMNE5956ME=GS1.1.1724847143.1.1.1724847172.31.0.0; _ga=GA1.2.243157588.1724847143',
    'priority': 'u=1, i',
    'referer': 'https://allbox.ru/korobki-iz-tonkogo-kartona/',
    'sec-ch-ua': '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}

params = {
    'result_ids': 'categories_view_pagination_contents,load_more_categories_view_pagination_contents,ut2_pagination_block,ut2_pagination_block_bottom',
    'is_ajax': '1',
}

response = requests.get('https://allbox.ru/korobki-iz-tonkogo-kartona/page-2/', 
                        params=params, 
                        # cookies=cookies, 
                        # headers=headers
                        )
response.json()
# Out:
# {'ab__sf_data': {'tag_h1': 'Коробки из картона',
#   'description': '',
#   'page_title': 'Купить коробки из картона для упаковки по доступным ценам с доставкой | Изготовление коробок из картона оптом и в розницу',
#   'replace_page_title': 'N'},
#  'current_url': 'https://allbox.ru/korobki-iz-tonkogo-kartona/page-2/',
#  'is_theme_editor_allowed': True,
# ...

# %%
with open('data/test/test.html', 'wb') as f:
    f.write(response.content)
